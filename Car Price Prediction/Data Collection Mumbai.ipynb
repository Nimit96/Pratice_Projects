# %%
from selenium import webdriver
import pandas as pd
import time
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys

# %%
driver = webdriver.Chrome("chromedriver.exe")
time.sleep(3)
url = 'https://www.carwale.com/'
driver.get(url)

# %%
clk = driver.find_element_by_xpath('//div[@class="o-bfyaNx o-dJmcbh o-eCFISO o-djSZRV o-fEEqXL o-bXKmQE"]')
clk.click()

# %%
key1 = driver.find_element_by_xpath('//input[@class="o-dqBOwT o-cKuOoN o-eZCpVk o-bfyaNx o-eZTujG o-jjpuv o-fzptVd o-fzptYr o-fEEqXL o-eKWNKE o-bIMsfE o-ItVGT  o-fznJFI E6NC89 _2XUNC9 _2aq9yP  E6NC89 "]')
key1.send_keys('Mumbai')
time.sleep(1)
clk1 = driver.find_element_by_xpath('//div[@class="o-lIIwF"]')
clk1.click()

# %%
srch = driver.find_element_by_xpath('//input[@class="cityName ui-autocomplete-input blur inputBlur"]')
srch.send_keys('Mumbai, Maharashtra')
time.sleep(1)
srch.send_keys(Keys.ENTER)

# %%
bod = driver.find_element_by_xpath('/html/body/div[12]/form/section[2]/div[1]/div[3]/div/div[1]/div[2]/div[4]/h3')
bod.click()
time.sleep(1)
hat = driver.find_element_by_xpath('/html/body/div[12]/form/section[2]/div[1]/div[3]/div/div[1]/div[2]/div[4]/div/ul/li[1]')
hat.click()

# %%
for i in range(0,500):
    driver.execute_script("window.scrollBy(0,5000)")

# %%
hatch_url = []
hatch = driver.find_elements_by_xpath('//a[@id="linkToDetails"]')

for i in hatch:
    hatch_url.append(i.get_attribute('href'))
len(hatch_url)
# Out:
# 246

# %%
price = []
year = []
make = []
model = []
fuel = []
trans = []
location = []
mile = []
color = []
owner =[]
engine = []
seating = []

for link in hatch_url:
    driver.get(link)
    time.sleep(3)
    try:
        pri = driver.find_element_by_xpath('//p[@class="used-actual"]')
        price.append(pri.text.replace('₹','').replace('Lakh',''))
    except NoSuchElementException:
        price.append('-')
        
    try:
        yea = driver.find_element_by_xpath('//div[@class="overview-list padding-bottom10"]//li[2]//div[2]')
        year.append(yea.text)
    except NoSuchElementException:
        year.append('-')
        
    try:
        mak = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[1]/div[1]/div[1]/ul/li[4]/a/span')
        make.append(mak.text)
    except NoSuchElementException:
        make.append('-')
        
    try:
        fu = driver.find_element_by_xpath('//div[@class="overview-list padding-bottom10"]//li[4]//div[2]')
        fuel.append(fu.text)
    except NoSuchElementException:
        fuel.append('-')
        
    try:
        tr = driver.find_element_by_xpath('//div[@class="overview-list padding-bottom10"]//li[5]//div[2]')
        trans.append(tr.text)
    except NoSuchElementException:
        trans.append('-')
        
    try:
        loc = driver.find_element_by_xpath('//div[@class="inline-block carlocationTxt break-word"]//p//span')
        location.append(loc.text)
    except NoSuchElementException:
        location.append('-')
        
    try:
        mod = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[1]/div[1]/div[1]/ul/li[5]/a/span')
        model.append(mod.text)
    except NoSuchElementException:
        model.append('-')
        
    try:
        mil = driver.find_element_by_xpath('//div[@class="overview-list padding-bottom10"]//li[3]//div[2]')
        mile.append(mil.text.replace(',','').replace('km',''))
    except NoSuchElementException:
        mile.append('-')

    try:
        col = driver.find_element_by_xpath('//div[@class="overview-list padding-bottom10"]//li[7]//div[2]')
        color.append(col.text)
    except NoSuchElementException:
        color.append('-')

    try:
        own = driver.find_element_by_xpath('//div[@class="overview-list padding-bottom10"]//li[9]//div[2]')
        owner.append(own.text)
    except NoSuchElementException:
        owner.append('-')
    time.sleep(2)

    try:
        driver.find_element_by_xpath('//div[@class="cw-tabs cw-tabs-flex cw-tabs-inner-margin0"]//li[3]').click()
        time.sleep(2)
        eng = driver.find_element_by_xpath('//*[@id="specifications"]/div/ul/li[1]/div[2]')
        engine.append(eng.text)
    except NoSuchElementException:
        engine.append('-')
        
    try:
        sea = driver.find_element_by_xpath('//*[@id="specifications"]/div/ul/li[3]/div[4]')
        seating.append(sea.text.replace('Person',''))
    except NoSuchElementException:
        seating.append('-')

# %%
hatch_mum = pd.DataFrame({})
hatch_mum['price'] = price
hatch_mum['year'] = year
hatch_mum['make'] = make
hatch_mum['model'] = model
hatch_mum['fuel'] = fuel
hatch_mum['trans'] = trans
hatch_mum['location'] = location
hatch_mum['mile'] = mile
hatch_mum['color'] = color
hatch_mum['owner'] = owner
hatch_mum['engine'] = engine
hatch_mum['seating'] = seating
hatch_mum.head()
# Out:
#      price      year           make      model    fuel      trans location  \
# 0    3.35   Jun 2011        Hyundai        i20  Petrol     Manual    Thane
# 1     4.2   Jun 2014  Maruti Suzuki      Swift  Petrol     Manual    Thane
# 2    5.65   Jun 2017        Hyundai  Grand i10  Petrol  Automatic   Mumbai
# 3   10.74   Jun 2020     Volkswagen       Polo  Petrol  Automatic   Mumbai
# 4     3.2   May 2013  Maruti Suzuki    Wagon R  Petrol     Manual   Mumbai
#
#      mile  color             owner  \
# 0  19130   White             First
# 1  56123     Red             First
# 2  44284   White             First
# 3   9100     Red  UnRegistered Car
# 4  41846   Brown             First
#
#                                               engine seating
# 0                                                  -       -
# 1  1197 cc, 4 Cylinders Inline, 4 Valves/Cylinder...      5
# 2  1197 cc, 4 Cylinders Inline, 4 Valves/Cylinder...      5
# 3  1197 cc, 4 Cylinders Inline, 4 Valves/Cylinder...      5
# 4              998 cc, 3 Cylinders 4 Valves/Cylinder      5

# %%
hatch_mum['year'] = pd.to_numeric(hatch_mum['year'].str.split(' ', expand = True)[1])

# %%
hatch_mum
# Out:
#        price    year           make      model    fuel      trans location  \
# 0      3.35   2011.0        Hyundai        i20  Petrol     Manual    Thane
# 1       4.2   2014.0  Maruti Suzuki      Swift  Petrol     Manual    Thane
# 2      5.65   2017.0        Hyundai  Grand i10  Petrol  Automatic   Mumbai
# 3     10.74   2020.0     Volkswagen       Polo  Petrol  Automatic   Mumbai
# 4       3.2   2013.0  Maruti Suzuki    Wagon R  Petrol     Manual   Mumbai
# ..       ...     ...            ...        ...     ...        ...      ...
# 241    4.75   2014.0  Maruti Suzuki      Swift  Diesel     Manual   Mumbai
# 242    3.24   2012.0        Hyundai        i10  Petrol  Automatic   Mumbai
# 243    7.25   2018.0  Maruti Suzuki     Baleno  Petrol  Automatic   Mumbai
# 244       5   2016.0  Maruti Suzuki      Swift  Diesel     Manual   Mumbai
# 245     2.7   2016.0        Renault       Kwid  Petrol     Manual   Mumbai
#
#        mile   color             owner  \
# 0    19130    White             First
# 1    56123      Red             First
# 2    44284    White             First
# 3     9100      Red  UnRegistered Car
# 4    41846    Brown             First
# ..      ...     ...               ...
# 241  72000     Grey             First
# 242  30000    White             First
# 243  26200   Silver            Second
# 244  50900     Grey             First
# 245  39600   Silver            Second
#
#                                                 engine seating
# 0                                                    -       -
# 1    1197 cc, 4 Cylinders Inline, 4 Valves/Cylinder...      5
# 2    1197 cc, 4 Cylinders Inline, 4 Valves/Cylinder...      5
# 3    1197 cc, 4 Cylinders Inline, 4 Valves/Cylinder...      5
# 4                998 cc, 3 Cylinders 4 Valves/Cylinder      5
# ..                                                 ...     ...
# 241  1248 cc, 4 Cylinders Inline, 4 Valves/Cylinder...      5
# 242  1197 cc, 4 Cylinders Inline, 4 Valves/Cylinder...      5
# 243  1197 cc, 4 Cylinders Inline, 4 Valves/Cylinder...      5
# 244  1248 cc, 4 Cylinders Inline, 4 Valves/Cylinder...      5
# 245  799 cc, 3 Cylinders Inline, 4 Valves/Cylinder,...      5
#
# [246 rows x 12 columns]

# %%
driver = webdriver.Chrome("chromedriver.exe")
time.sleep(3)
url = 'https://www.carwale.com/'
driver.get(url)

# %%
clk = driver.find_element_by_xpath('//div[@class="o-bfyaNx o-dJmcbh o-eCFISO o-djSZRV o-fEEqXL o-bXKmQE"]')
clk.click()
time.sleep(2)
key1 = driver.find_element_by_xpath('//input[@class="o-dqBOwT o-cKuOoN o-eZCpVk o-bfyaNx o-eZTujG o-jjpuv o-fzptVd o-fzptYr o-fEEqXL o-eKWNKE o-bIMsfE o-ItVGT  o-fznJFI E6NC89 _2XUNC9 _2aq9yP  E6NC89 "]')
key1.send_keys('Mumbai')
time.sleep(1)
clk1 = driver.find_element_by_xpath('//div[@class="o-lIIwF"]')
clk1.click()
time.sleep(4)

# %%
srch = driver.find_element_by_xpath('//input[@class="cityName ui-autocomplete-input blur inputBlur"]')
srch.send_keys('Mumbai, Maharashtra')
time.sleep(1)
srch.send_keys(Keys.ENTER)

# %%
bod = driver.find_element_by_xpath('/html/body/div[12]/form/section[2]/div[1]/div[3]/div/div[1]/div[2]/div[4]/h3')
bod.click()
time.sleep(3)
hat = driver.find_element_by_xpath('/html/body/div[12]/form/section[2]/div[1]/div[3]/div/div[1]/div[2]/div[4]/div/ul/li[3]/span[1]')
hat.click()

# %%
for i in range(0,500):
    driver.execute_script("window.scrollBy(0,5000)")
    driver.execute_script("window.scrollBy(0,-500)")

# %%
suv_url = []
suv = driver.find_elements_by_xpath('//a[@id="linkToDetails"]')

for i in suv:
    suv_url.append(i.get_attribute('href'))
len(suv_url)
# Out:
# 247

# %%
price = []
year = []
make = []
model = []
fuel = []
trans = []
location = []
mile = []
color = []
owner =[]
engine = []
seating = []

for link in suv_url:
    driver.get(link)
    time.sleep(3)
    try:
        pri = driver.find_element_by_xpath('//p[@class="used-actual"]')
        price.append(pri.text.replace('₹','').replace('Lakh',''))
    except NoSuchElementException:
        price.append('-')
        
    try:
        yea = driver.find_element_by_xpath('//div[@class="overview-list padding-bottom10"]//li[2]//div[2]')
        year.append(yea.text)
    except NoSuchElementException:
        year.append('-')
        
    try:
        mak = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[1]/div[1]/div[1]/ul/li[4]/a/span')
        make.append(mak.text)
    except NoSuchElementException:
        make.append('-')
        
    try:
        fu = driver.find_element_by_xpath('//div[@class="overview-list padding-bottom10"]//li[4]//div[2]')
        fuel.append(fu.text)
    except NoSuchElementException:
        fuel.append('-')
        
    try:
        tr = driver.find_element_by_xpath('//div[@class="overview-list padding-bottom10"]//li[5]//div[2]')
        trans.append(tr.text)
    except NoSuchElementException:
        trans.append('-')
        
    try:
        loc = driver.find_element_by_xpath('//div[@class="inline-block carlocationTxt break-word"]//p//span')
        location.append(loc.text)
    except NoSuchElementException:
        location.append('-')
        
    try:
        mod = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[1]/div[1]/div[1]/ul/li[5]/a/span')
        model.append(mod.text)
    except NoSuchElementException:
        model.append('-')
        
    try:
        mil = driver.find_element_by_xpath('//div[@class="overview-list padding-bottom10"]//li[3]//div[2]')
        mile.append(mil.text.replace(',','').replace('km',''))
    except NoSuchElementException:
        mile.append('-')

    try:
        col = driver.find_element_by_xpath('//div[@class="overview-list padding-bottom10"]//li[7]//div[2]')
        color.append(col.text)
    except NoSuchElementException:
        color.append('-')

    try:
        own = driver.find_element_by_xpath('//div[@class="overview-list padding-bottom10"]//li[9]//div[2]')
        owner.append(own.text)
    except NoSuchElementException:
        owner.append('-')
    time.sleep(2)

    try:
        driver.find_element_by_xpath('//div[@class="cw-tabs cw-tabs-flex cw-tabs-inner-margin0"]//li[3]').click()
        time.sleep(2)
        eng = driver.find_element_by_xpath('//*[@id="specifications"]/div/ul/li[1]/div[2]')
        engine.append(eng.text)
    except NoSuchElementException:
        engine.append('-')
        
    try:
        sea = driver.find_element_by_xpath('//*[@id="specifications"]/div/ul/li[3]/div[4]')
        seating.append(sea.text.replace('Person',''))
    except NoSuchElementException:
        seating.append('-')

# %%
suv_mum = pd.DataFrame({})
suv_mum['price'] = price
suv_mum['year'] = year
suv_mum['make'] = make
suv_mum['model'] = model
suv_mum['fuel'] = fuel
suv_mum['trans'] = trans
suv_mum['location'] = location
suv_mum['mile'] = mile
suv_mum['color'] = color
suv_mum['owner'] = owner
suv_mum['engine'] = engine
suv_mum['seating'] = seating
suv_mum.head()
# Out:
#      price      year           make      model    fuel      trans location  \
# 0    3.35   Jun 2011        Hyundai        i20  Petrol     Manual    Thane
# 1     4.2   Jun 2014  Maruti Suzuki      Swift  Petrol     Manual    Thane
# 2    5.65   Jun 2017        Hyundai  Grand i10  Petrol  Automatic   Mumbai
# 3   10.74   Jun 2020     Volkswagen       Polo  Petrol  Automatic   Mumbai
# 4     3.2   May 2013  Maruti Suzuki    Wagon R  Petrol     Manual   Mumbai
#
#      mile  color             owner  \
# 0  19130   White             First
# 1  56123     Red             First
# 2  44284   White             First
# 3   9100     Red  UnRegistered Car
# 4  41846   Brown             First
#
#                                               engine seating
# 0                                                  -       -
# 1  1197 cc, 4 Cylinders Inline, 4 Valves/Cylinder...      5
# 2  1197 cc, 4 Cylinders Inline, 4 Valves/Cylinder...      5
# 3  1197 cc, 4 Cylinders Inline, 4 Valves/Cylinder...      5
# 4              998 cc, 3 Cylinders 4 Valves/Cylinder      5

# %%
suv_mum.tail(10)
# Out:
#        price      year           make     model    fuel      trans  \
# 484    7.25   Mar 2018           Tata     Nexon  Petrol     Manual
# 485    33.5   Jun 2011        Porsche   Cayenne  Petrol  Automatic
# 486      20   Jun 2016  Mercedes-Benz       GLA  Petrol  Automatic
# 487    22.5   Jun 2014           Audi        Q7  Diesel  Automatic
# 488    42.5   Jun 2015  Mercedes-Benz       GLE  Diesel  Automatic
# 489    20.5   Jun 2016  Mercedes-Benz       GLA  Petrol  Automatic
# 490     6.5   Jun 2011        Hyundai  Santa Fe  Diesel     Manual
# 491      32   Jun 2016  Mercedes-Benz       GLC  Diesel  Automatic
# 492    8.95   Jun 2018           Tata      Hexa  Diesel     Manual
# 493   27.95   Jun 2017         Toyota  Fortuner  Diesel     Manual
#
#         location     mile  color   owner  \
# 484       Mumbai    9860     Red   First
# 485       Mumbai   29000    Blue   First
# 486       Mumbai   33000     Red  Second
# 487       Mumbai  107000    Blue  Second
# 488       Mumbai   49000   White   First
# 489       Mumbai   36000   White   First
# 490  Navi Mumbai  170000   White   Third
# 491       Mumbai   65121   White  Second
# 492       Mumbai   77500   White  Second
# 493       Mumbai   22700   White   First
#
#                                                 engine seating
# 484  1198 cc, 3 Cylinders Inline, 4 Valves/Cylinder...      5
# 485  4806 cc, 8 Cylinders In V Shape, 4 Valves/Cyli...      5
# 486  1991 cc, 4 Cylinders Inline, 4 Valves/Cylinder...      5
# 487  2967 cc, 6 Cylinders In V Shape, 4 Valves/Cyli...      7
# 488  2987 cc, 6 Cylinders In V Shape, 4 Valves/Cyli...      5
# 489  1991 cc, 4 Cylinders Inline, 4 Valves/Cylinder...      5
# 490  2199 cc, 4 Cylinders Inline, 4 Valves/Cylinder...      7
# 491  2143 cc, 4 Cylinders Inline, 4 Valves/Cylinder...      5
# 492  2179 cc, 4 Cylinders Inline, 4 Valves/Cylinder...      7
# 493  2755 cc, 4 Cylinders Inline, 4 Valves/Cylinder...      7

# %%
suv_mum = suv_mum.iloc[247:,:]
suv_mum.head()
# Out:
#        price      year           make          model    fuel      trans  \
# 247    9.85   Jun 2018  Maruti Suzuki  Vitara Brezza  Diesel     Manual
# 248      24   Jan 2016  Mercedes-Benz            GLA  Petrol  Automatic
# 249   14.11   Mar 2018        Hyundai          Creta  Petrol  Automatic
# 250    54.5   Aug 2018  Mercedes-Benz            GLE  Diesel  Automatic
# 251    4.15   Jun 2011       Mahindra        Scorpio  Diesel     Manual
#
#     location    mile  color  owner  \
# 247    Thane  34123    Blue  First
# 248   Mumbai  48305   White  First
# 249   Mumbai  38000    Grey  First
# 250   Mumbai  22719   Black  First
# 251    Thane  88258    Grey  First
#
#                                                 engine seating
# 247  1248 cc, 4 Cylinders Inline, 4 Valves/Cylinder...      5
# 248  1991 cc, 4 Cylinders Inline, 4 Valves/Cylinder...      5
# 249  1591 cc, 4 Cylinders Inline, 4 Valves/Cylinder...      5
# 250  2143 cc, 4 Cylinders Inline, 4 Valves/Cylinder...      5
# 251  2179 cc, 4 Cylinders Inline, 4 Valves/Cylinder...  7 & 9

# %%
hatch_mum['Body'] = 'hatchback'
suv_mum['Body'] = 'SUV'

# %%
suv_mum.head()
# Out:
#        price      year           make          model    fuel      trans  \
# 247    9.85   Jun 2018  Maruti Suzuki  Vitara Brezza  Diesel     Manual
# 248      24   Jan 2016  Mercedes-Benz            GLA  Petrol  Automatic
# 249   14.11   Mar 2018        Hyundai          Creta  Petrol  Automatic
# 250    54.5   Aug 2018  Mercedes-Benz            GLE  Diesel  Automatic
# 251    4.15   Jun 2011       Mahindra        Scorpio  Diesel     Manual
#
#     location    mile  color  owner  \
# 247    Thane  34123    Blue  First
# 248   Mumbai  48305   White  First
# 249   Mumbai  38000    Grey  First
# 250   Mumbai  22719   Black  First
# 251    Thane  88258    Grey  First
#
#                                                 engine seating Body
# 247  1248 cc, 4 Cylinders Inline, 4 Valves/Cylinder...      5   SUV
# 248  1991 cc, 4 Cylinders Inline, 4 Valves/Cylinder...      5   SUV
# 249  1591 cc, 4 Cylinders Inline, 4 Valves/Cylinder...      5   SUV
# 250  2143 cc, 4 Cylinders Inline, 4 Valves/Cylinder...      5   SUV
# 251  2179 cc, 4 Cylinders Inline, 4 Valves/Cylinder...  7 & 9   SUV

# %%
driver = webdriver.Chrome("chromedriver.exe")
time.sleep(3)
url = 'https://www.carwale.com/'
driver.get(url)
time.sleep(5)
clk = driver.find_element_by_xpath('//div[@class="o-bfyaNx o-dJmcbh o-eCFISO o-djSZRV o-fEEqXL o-bXKmQE"]')
clk.click()
time.sleep(2)
key1 = driver.find_element_by_xpath('//input[@class="o-dqBOwT o-cKuOoN o-eZCpVk o-bfyaNx o-eZTujG o-jjpuv o-fzptVd o-fzptYr o-fEEqXL o-eKWNKE o-bIMsfE o-ItVGT  o-fznJFI E6NC89 _2XUNC9 _2aq9yP  E6NC89 "]')
key1.send_keys('Mumbai')
time.sleep(1)
clk1 = driver.find_element_by_xpath('//div[@class="o-lIIwF"]')
clk1.click()
time.sleep(10)

# %%
srch = driver.find_element_by_xpath('//input[@class="cityName ui-autocomplete-input blur inputBlur"]')
srch.send_keys('Mumbai, Maharashtra')
time.sleep(1)
srch.send_keys(Keys.ENTER)
time.sleep(6)
bod = driver.find_element_by_xpath('/html/body/div[12]/form/section[2]/div[1]/div[3]/div/div[1]/div[2]/div[4]/h3')
bod.click()
time.sleep(3)

# %%
hat = driver.find_element_by_xpath('/html/body/div[12]/form/section[2]/div[1]/div[3]/div/div[1]/div[2]/div[4]/div/ul/li[7]/span[1]')
hat.click()

# %%
for i in range(0,500):
    driver.execute_script("window.scrollBy(0,5000)")
    driver.execute_script("window.scrollBy(0,-500)")

# %%
sdn_url = []
sdn = driver.find_elements_by_xpath('//a[@id="linkToDetails"]')

for i in sdn:
    sdn_url.append(i.get_attribute('href'))
len(sdn_url)
# Out:
# 246

# %%
sprice = []
syear = []
smake = []
smodel = []
sfuel = []
strans = []
slocation = []
smile = []
scolor = []
sowner =[]
sengine = []
sseating = []

for link in sdn_url:
    driver.get(link)
    time.sleep(3)
    try:
        pri = driver.find_element_by_xpath('//p[@class="used-actual"]')
        sprice.append(pri.text.replace('₹','').replace('Lakh',''))
    except NoSuchElementException:
        sprice.append('-')
        
    try:
        yea = driver.find_element_by_xpath('//div[@class="overview-list padding-bottom10"]//li[2]//div[2]')
        syear.append(yea.text)
    except NoSuchElementException:
        syear.append('-')
        
    try:
        mak = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[1]/div[1]/div[1]/ul/li[4]/a/span')
        smake.append(mak.text)
    except NoSuchElementException:
        smake.append('-')
        
    try:
        fu = driver.find_element_by_xpath('//div[@class="overview-list padding-bottom10"]//li[4]//div[2]')
        sfuel.append(fu.text)
    except NoSuchElementException:
        sfuel.append('-')
        
    try:
        tr = driver.find_element_by_xpath('//div[@class="overview-list padding-bottom10"]//li[5]//div[2]')
        strans.append(tr.text)
    except NoSuchElementException:
        strans.append('-')
        
    try:
        loc = driver.find_element_by_xpath('//div[@class="inline-block carlocationTxt break-word"]//p//span')
        slocation.append(loc.text)
    except NoSuchElementException:
        slocation.append('-')
        
    try:
        mod = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[1]/div[1]/div[1]/ul/li[5]/a/span')
        smodel.append(mod.text)
    except NoSuchElementException:
        smodel.append('-')
        
    try:
        mil = driver.find_element_by_xpath('//div[@class="overview-list padding-bottom10"]//li[3]//div[2]')
        smile.append(mil.text.replace(',','').replace('km',''))
    except NoSuchElementException:
        smile.append('-')

    try:
        col = driver.find_element_by_xpath('//div[@class="overview-list padding-bottom10"]//li[7]//div[2]')
        scolor.append(col.text)
    except NoSuchElementException:
        scolor.append('-')

    try:
        own = driver.find_element_by_xpath('//div[@class="overview-list padding-bottom10"]//li[9]//div[2]')
        sowner.append(own.text)
    except NoSuchElementException:
        sowner.append('-')
    time.sleep(2)

    try:
        driver.find_element_by_xpath('//div[@class="cw-tabs cw-tabs-flex cw-tabs-inner-margin0"]//li[3]').click()
        time.sleep(2)
        eng = driver.find_element_by_xpath('//*[@id="specifications"]/div/ul/li[1]/div[2]')
        sengine.append(eng.text)
    except NoSuchElementException:
        sengine.append('-')
        
    try:
        sea = driver.find_element_by_xpath('//*[@id="specifications"]/div/ul/li[3]/div[4]')
        sseating.append(sea.text.replace('Person',''))
    except NoSuchElementException:
        sseating.append('-')

# %%
sdn_mum = pd.DataFrame({})
sdn_mum['price'] = sprice
sdn_mum['year'] = syear
sdn_mum['make'] = smake
sdn_mum['model'] = smodel
sdn_mum['fuel'] = sfuel
sdn_mum['trans'] = strans
sdn_mum['location'] = slocation
sdn_mum['mile'] = smile
sdn_mum['color'] = scolor
sdn_mum['owner'] = sowner
sdn_mum['engine'] = sengine
sdn_mum['seating'] = sseating
sdn_mum['Body'] = 'sedan'
sdn_mum.head()
# Out:
#      price      year           make    model    fuel      trans location  \
# 0   12.58   Jan 2011  Mercedes-Benz  C-Class  Petrol  Automatic   Mumbai
# 1    18.9   Jun 2017          Skoda  Octavia  Diesel  Automatic   Mumbai
# 2    19.5   Jun 2014         Jaguar       XF  Diesel  Automatic   Mumbai
# 3    24.5   Jun 2019          Skoda   Superb  Petrol  Automatic   Mumbai
# 4    12.5   Jun 2011           Audi       A6  Petrol  Automatic   Mumbai
#
#      mile  color   owner                                             engine  \
# 0  66700   White   First                               1796 cc, 4 Cylinders
# 1  27000   Black   First  1968 cc, 4 Cylinders Inline, 4 Valves/Cylinder...
# 2  61000   White   First  2179 cc, 4 Cylinders Inline, 4 Valves/Cylinder...
# 3  17000   White   First  1798 cc, 4 Cylinders Inline, 4 Valves/Cylinder...
# 4  40000   Black  Second                                                  -
#
#   seating   Body
# 0      5   sedan
# 1      5   sedan
# 2      5   sedan
# 3      5   sedan
# 4       -  sedan

# %%
driver = webdriver.Chrome("chromedriver.exe")
time.sleep(3)
url = 'https://www.carwale.com/'
driver.get(url)
time.sleep(5)
clk = driver.find_element_by_xpath('//div[@class="o-bfyaNx o-dJmcbh o-eCFISO o-djSZRV o-fEEqXL o-bXKmQE"]')
clk.click()
time.sleep(2)
key1 = driver.find_element_by_xpath('//input[@class="o-dqBOwT o-cKuOoN o-eZCpVk o-bfyaNx o-eZTujG o-jjpuv o-fzptVd o-fzptYr o-fEEqXL o-eKWNKE o-bIMsfE o-ItVGT  o-fznJFI E6NC89 _2XUNC9 _2aq9yP  E6NC89 "]')
key1.send_keys('Mumbai')
time.sleep(1)
clk1 = driver.find_element_by_xpath('//div[@class="o-lIIwF"]')
clk1.click()
time.sleep(20)

# %%
srch = driver.find_element_by_xpath('//input[@class="cityName ui-autocomplete-input blur inputBlur"]')
srch.send_keys('Mumbai, Maharashtra')
time.sleep(1)
srch.send_keys(Keys.ENTER)
time.sleep(6)
bod = driver.find_element_by_xpath('/html/body/div[12]/form/section[2]/div[1]/div[3]/div/div[1]/div[2]/div[4]/h3')
bod.click()
time.sleep(3)

# %%
hat = driver.find_element_by_xpath('/html/body/div[12]/form/section[2]/div[1]/div[3]/div/div[1]/div[2]/div[4]/div/ul/li[4]/span[1]')
hat.click()

# %%
for i in range(0,100):
    driver.execute_script("window.scrollBy(0,5000)")
    driver.execute_script("window.scrollBy(0,-500)")

# %%
van_url = []
van = driver.find_elements_by_xpath('//a[@id="linkToDetails"]')

for i in van:
    van_url.append(i.get_attribute('href'))
len(van_url)
# Out:
# 54

# %%
vprice = []
vyear = []
vmake = []
vmodel = []
vfuel = []
vtrans = []
vlocation = []
vmile = []
vcolor = []
vowner =[]
vengine = []
vseating = []

for link in van_url:
    driver.get(link)
    time.sleep(3)
    try:
        pri = driver.find_element_by_xpath('//p[@class="used-actual"]')
        vprice.append(pri.text.replace('₹','').replace('Lakh',''))
    except NoSuchElementException:
        vprice.append('-')
        
    try:
        yea = driver.find_element_by_xpath('//div[@class="overview-list padding-bottom10"]//li[2]//div[2]')
        vyear.append(yea.text)
    except NoSuchElementException:
        vyear.append('-')
        
    try:
        mak = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[1]/div[1]/div[1]/ul/li[4]/a/span')
        vmake.append(mak.text)
    except NoSuchElementException:
        vmake.append('-')
        
    try:
        fu = driver.find_element_by_xpath('//div[@class="overview-list padding-bottom10"]//li[4]//div[2]')
        vfuel.append(fu.text)
    except NoSuchElementException:
        vfuel.append('-')
        
    try:
        tr = driver.find_element_by_xpath('//div[@class="overview-list padding-bottom10"]//li[5]//div[2]')
        vtrans.append(tr.text)
    except NoSuchElementException:
        strans.append('-')
        
    try:
        loc = driver.find_element_by_xpath('//div[@class="inline-block carlocationTxt break-word"]//p//span')
        vlocation.append(loc.text)
    except NoSuchElementException:
        vlocation.append('-')
        
    try:
        mod = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[1]/div[1]/div[1]/ul/li[5]/a/span')
        vmodel.append(mod.text)
    except NoSuchElementException:
        vmodel.append('-')
        
    try:
        mil = driver.find_element_by_xpath('//div[@class="overview-list padding-bottom10"]//li[3]//div[2]')
        vmile.append(mil.text.replace(',','').replace('km',''))
    except NoSuchElementException:
        vmile.append('-')

    try:
        col = driver.find_element_by_xpath('//div[@class="overview-list padding-bottom10"]//li[7]//div[2]')
        vcolor.append(col.text)
    except NoSuchElementException:
        vcolor.append('-')

    try:
        own = driver.find_element_by_xpath('//div[@class="overview-list padding-bottom10"]//li[9]//div[2]')
        vowner.append(own.text)
    except NoSuchElementException:
        vowner.append('-')
    time.sleep(2)

    try:
        driver.find_element_by_xpath('//div[@class="cw-tabs cw-tabs-flex cw-tabs-inner-margin0"]//li[3]').click()
        time.sleep(2)
        eng = driver.find_element_by_xpath('//*[@id="specifications"]/div/ul/li[1]/div[2]')
        vengine.append(eng.text)
    except NoSuchElementException:
        vengine.append('-')
        
    try:
        sea = driver.find_element_by_xpath('//*[@id="specifications"]/div/ul/li[3]/div[4]')
        vseating.append(sea.text.replace('Person',''))
    except NoSuchElementException:
        vseating.append('-')

# %%
van_mum = pd.DataFrame({})
van_mum['price'] = vprice
van_mum['year'] = vyear
van_mum['make'] = vmake
van_mum['model'] = vmodel
van_mum['fuel'] = vfuel
van_mum['trans'] = vtrans
van_mum['location'] = vlocation
van_mum['mile'] = vmile
van_mum['color'] = vcolor
van_mum['owner'] = vowner
van_mum['engine'] = vengine
van_mum['seating'] = vseating
van_mum['Body'] = 'minivan'
van_mum.head()
# Out:
#     price      year           make model       fuel   trans location    mile  \
# 0   3.85   Feb 2019  Maruti Suzuki  Eeco        CNG  Manual   Mumbai  40000
# 1   5.15   Aug 2019  Maruti Suzuki  Eeco     Petrol  Manual    Thane   6432
# 2   3.11   Jun 2013  Maruti Suzuki  Eeco     Petrol  Manual    Thane  48000
# 3   3.65   Jun 2016  Maruti Suzuki  Eeco  CNG + Cng  Manual   Mumbai  71864
# 4    5.3   Jun 2020  Maruti Suzuki  Eeco  CNG + Cng  Manual   Mumbai   4400
#
#     color   owner                                             engine seating  \
# 0   White   First  1196 cc, 4 Cylinders Inline, 4 Valves/Cylinder...      5
# 1    Grey   First  1196 cc, 4 Cylinders Inline, 4 Valves/Cylinder...      5
# 2    Grey  Second  1196 cc, 4 Cylinders Inline, 4 Valves/Cylinder...      5
# 3   Black  Second  1196 cc, 4 Cylinders Inline, 4 Valves/Cylinder...      5
# 4  Silver   First  1196 cc, 4 Cylinders Inline, 4 Valves/Cylinder...      5
#
#       Body
# 0  minivan
# 1  minivan
# 2  minivan
# 3  minivan
# 4  minivan

# %%
driver = webdriver.Chrome("chromedriver.exe")
time.sleep(3)
url = 'https://www.carwale.com/'
driver.get(url)
time.sleep(5)
clk = driver.find_element_by_xpath('//div[@class="o-bfyaNx o-dJmcbh o-eCFISO o-djSZRV o-fEEqXL o-bXKmQE"]')
clk.click()
time.sleep(2)
key1 = driver.find_element_by_xpath('//input[@class="o-dqBOwT o-cKuOoN o-eZCpVk o-bfyaNx o-eZTujG o-jjpuv o-fzptVd o-fzptYr o-fEEqXL o-eKWNKE o-bIMsfE o-ItVGT  o-fznJFI E6NC89 _2XUNC9 _2aq9yP  E6NC89 "]')
key1.send_keys('Mumbai')
time.sleep(1)
clk1 = driver.find_element_by_xpath('//div[@class="o-lIIwF"]')
clk1.click()

# %%
srch = driver.find_element_by_xpath('//input[@class="cityName ui-autocomplete-input blur inputBlur"]')
srch.send_keys('Mumbai, Maharashtra')
time.sleep(1)
srch.send_keys(Keys.ENTER)
time.sleep(6)
bod = driver.find_element_by_xpath('/html/body/div[12]/form/section[2]/div[1]/div[3]/div/div[1]/div[2]/div[4]/h3')
bod.click()
time.sleep(3)

# %%
hat = driver.find_element_by_xpath('/html/body/div[12]/form/section[2]/div[1]/div[3]/div/div[1]/div[2]/div[4]/div/ul/li[2]/span[1]')
hat.click()
time.sleep(10)
hat1 = driver.find_element_by_xpath('/html/body/div[12]/form/section[2]/div[1]/div[3]/div/div[1]/div[2]/div[4]/div/ul/li[8]/span[1]')
hat1.click()

# %%
for i in range(0,100):
    driver.execute_script("window.scrollBy(0,5000)")
    driver.execute_script("window.scrollBy(0,-500)")

# %%
cpe_url = []
cpe = driver.find_elements_by_xpath('//a[@id="linkToDetails"]')

for i in cpe:
    cpe_url.append(i.get_attribute('href'))
len(cpe_url)
# Out:
# 48

# %%
cprice = []
cyear = []
cmake = []
cmodel = []
cfuel = []
ctrans = []
clocation = []
cmile = []
ccolor = []
cowner =[]
cengine = []
cseating = []

for link in cpe_url:
    driver.get(link)
    time.sleep(3)
    try:
        pri = driver.find_element_by_xpath('//p[@class="used-actual"]')
        cprice.append(pri.text.replace('₹','').replace('Lakh',''))
    except NoSuchElementException:
        cprice.append('-')
        
    try:
        yea = driver.find_element_by_xpath('//div[@class="overview-list padding-bottom10"]//li[2]//div[2]')
        cyear.append(yea.text)
    except NoSuchElementException:
        cyear.append('-')
        
    try:
        mak = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[1]/div[1]/div[1]/ul/li[4]/a/span')
        cmake.append(mak.text)
    except NoSuchElementException:
        cmake.append('-')
        
    try:
        fu = driver.find_element_by_xpath('//div[@class="overview-list padding-bottom10"]//li[4]//div[2]')
        cfuel.append(fu.text)
    except NoSuchElementException:
        cfuel.append('-')
        
    try:
        tr = driver.find_element_by_xpath('//div[@class="overview-list padding-bottom10"]//li[5]//div[2]')
        ctrans.append(tr.text)
    except NoSuchElementException:
        ctrans.append('-')
        
    try:
        loc = driver.find_element_by_xpath('//div[@class="inline-block carlocationTxt break-word"]//p//span')
        clocation.append(loc.text)
    except NoSuchElementException:
        clocation.append('-')
        
    try:
        mod = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[1]/div[1]/div[1]/ul/li[5]/a/span')
        cmodel.append(mod.text)
    except NoSuchElementException:
        cmodel.append('-')
        
    try:
        mil = driver.find_element_by_xpath('//div[@class="overview-list padding-bottom10"]//li[3]//div[2]')
        cmile.append(mil.text.replace(',','').replace('km',''))
    except NoSuchElementException:
        cmile.append('-')

    try:
        col = driver.find_element_by_xpath('//div[@class="overview-list padding-bottom10"]//li[7]//div[2]')
        ccolor.append(col.text)
    except NoSuchElementException:
        ccolor.append('-')

    try:
        own = driver.find_element_by_xpath('//div[@class="overview-list padding-bottom10"]//li[9]//div[2]')
        cowner.append(own.text)
    except NoSuchElementException:
        cowner.append('-')
    time.sleep(2)

    try:
        try:
            driver.find_element_by_xpath('//div[@class="cw-tabs cw-tabs-flex cw-tabs-inner-margin0"]//li[3]').click()
            time.sleep(2)
            eng = driver.find_element_by_xpath('//*[@id="specifications"]/div/ul/li[1]/div[2]')
            cengine.append(eng.text)
        except NoSuchElementException:
            cengine.append('-')
    except ElementClickInterceptedException:
        cengine.append('-')
        
    try:
        sea = driver.find_element_by_xpath('//*[@id="specifications"]/div/ul/li[3]/div[4]')
        cseating.append(sea.text.replace('Person',''))
    except NoSuchElementException:
        cseating.append('-')

# %%
cpe_mum = pd.DataFrame({})
cpe_mum['price'] = cprice
cpe_mum['year'] = cyear
cpe_mum['make'] = cmake
cpe_mum['model'] = cmodel
cpe_mum['fuel'] = cfuel
cpe_mum['trans'] = ctrans
cpe_mum['location'] = clocation
cpe_mum['mile'] = cmile
cpe_mum['color'] = ccolor
cpe_mum['owner'] = cowner
cpe_mum['engine'] = cengine
cpe_mum['seating'] = cseating
cpe_mum['Body'] = 'coupe/convertible'
cpe_mum.head()
# Out:
#     price      year           make     model    fuel      trans     location  \
# 0   38.5   Jun 2013  Mercedes-Benz   E-Class  Petrol  Automatic       Mumbai
# 1     32   Apr 2013            BMW  6-Series  Diesel  Automatic  Navi Mumbai
# 2     77   Jun 2019            BMW        M2  Petrol  Automatic         Pune
# 3     45   Jun 2010           Audi        R8  Petrol  Automatic         Pune
# 4   39.9   Dec 2015           Audi        TT  Petrol  Automatic       Mumbai
#
#      mile   color             owner  \
# 0   6000   Yellow             First
# 1  34000    Black             First
# 2   2905   Orange  UnRegistered Car
# 3  20519   Silver             Third
# 4  10000    White             First
#
#                                               engine seating  \
# 0  3498 cc, 6 Cylinders In V Shape, 4 Valves/Cyli...      4
# 1     2993 cc, 6 Cylinders Inline, 4 Valves/Cylinder      5
# 2                                           250 Kmph      4
# 3                                                  -       -
# 4  1984 cc, 4 Cylinders Inline, 4 Valves/Cylinder...      2
#
#                 Body
# 0  coupe/convertible
# 1  coupe/convertible
# 2  coupe/convertible
# 3  coupe/convertible
# 4  coupe/convertible

# %%
cpe_mum
# Out:
#           price      year           make              model             fuel  \
# 0         38.5   Jun 2013  Mercedes-Benz            E-Class           Petrol
# 1           32   Apr 2013            BMW           6-Series           Diesel
# 2           77   Jun 2019            BMW                 M2           Petrol
# 3           45   Jun 2010           Audi                 R8           Petrol
# 4         39.9   Dec 2015           Audi                 TT           Petrol
# 5           45   Jun 2018           MINI        Convertible           Petrol
# 6           24   Jun 2010  Mercedes-Benz          SLK-Class           Petrol
# 7           24   Jun 2010  Mercedes-Benz          SLK-Class           Petrol
# 8        18.25   Jun 2013           MINI             Cooper           Petrol
# 9         52.5   Jan 2016           Audi                 TT           Petrol
# 10        43.5   Jun 2015           Audi                 TT           Petrol
# 11        67.5   Jun 2017           Ford            Mustang           Petrol
# 12          37   Mar 2015           Audi                 A3           Petrol
# 13          80   Jun 2007        Bentley    Continental GTC           Petrol
# 14          75   May 2019            BMW                 Z4           Petrol
# 15          82   Mar 2013   Aston Martin            Vantage           Petrol
# 16          75   Jun 2012       Maserati        GranTurismo           Petrol
# 17          95   Mar 2017        Porsche                718           Petrol
# 18          28   Jun 2013            BMW           6-Series           Diesel
# 19       34.95   Jun 2012           Audi                RS5           Petrol
# 20          32   Mar 2013            BMW           6-Series           Diesel
# 21          75   Aug 2017  Mercedes-Benz                SLC           Petrol
# 22          65   Jun 2013         Jaguar             F-type           Petrol
# 23          55   Apr 2017           Audi                 A3           Petrol
# 24        69.9   Apr 2014            BMW                 M6           Petrol
# 25        69.9   Oct 2018           Audi       A5 Cabriolet           Diesel
# 26          33   Jan 2012            BMW           3-Series           Diesel
# 27   1.15 Crore  Jun 2016        Porsche                911           Petrol
# 28        38.5   Jun 2012            BMW           6-Series           Diesel
# 29        53.5   Jun 2017  Mercedes-Benz  C-Class Cabriolet           Petrol
# 30        46.5   Jan 2021           MINI        Convertible           Petrol
# 31       33.95   Jan 2016           Audi                 A3           Petrol
# 32          75   Jun 2008        Bentley     Continental GT           Petrol
# 33          45   Jun 2018           MINI        Convertible           Petrol
# 34          55   Jun 2017  Mercedes-Benz          GLC Coupe           Petrol
# 35   1.15 Crore  Jun 2016            BMW                 i8           Petrol
# 36        70.5   Jun 2017  Mercedes-Benz                SLC           Petrol
# 37   1.25 Crore  Jun 2011        Bentley     Continental GT           Petrol
# 38        18.5   Jun 2004          Lexus                 SC           Petrol
# 39          42   Mar 2012           Audi                RS5           Petrol
# 40          45   Jul 2011  Mercedes-Benz                 SL           Petrol
# 41          20   Dec 2008           Audi                 TT  Petrol + Petrol
# 42         9.9   Aug 2011            BMW           3-Series  Diesel + Diesel
# 43         1.5   Apr 2011      Chevrolet               Beat  Petrol + Petrol
# 44         1.3   Nov 2011      Chevrolet               Beat           Petrol
# 45          48   Jun 2013            BMW           6-Series           Petrol
# 46      3 Crore  Apr 2020    Lamborghini            Huracan           Petrol
# 47         8.5   Mar 2011            BMW           3-Series           Diesel
#
#         trans     location    mile          color             owner  \
# 0   Automatic       Mumbai   6000          Yellow             First
# 1   Automatic  Navi Mumbai  34000           Black             First
# 2   Automatic         Pune   2905          Orange  UnRegistered Car
# 3   Automatic         Pune  20519          Silver             Third
# 4   Automatic       Mumbai  10000           White             First
# 5   Automatic         Pune  10000            Blue             First
# 6   Automatic       Mumbai  28531             Red             First
# 7   Automatic       Mumbai  33652            Grey             First
# 8   Automatic       Mumbai  34121            Blue            Second
# 9   Automatic       Mumbai  19280            Blue             First
# 10  Automatic         Pune  18000             Red             First
# 11  Automatic       Mumbai  15000          Yellow             First
# 12  Automatic       Mumbai  14000             Red             Third
# 13  Automatic       Mumbai  45000           White             Third
# 14  Automatic       Mumbai   4000           White             First
# 15  Automatic       Mumbai  18000           White            Second
# 16  Automatic         Pune  12000             Red             First
# 17  Automatic       Mumbai   9000            Blue             First
# 18  Automatic       Mumbai  34512           White            Second
# 19  Automatic       Mumbai  22000            Blue             First
# 20  Automatic       Mumbai  41000           Black             First
# 21  Automatic       Mumbai   6000             Red             First
# 22  Automatic         Pune  19500             Red             Third
# 23  Automatic       Mumbai  20390           White             First
# 24     Manual       Mumbai   9000           White            Second
# 25  Automatic       Mumbai   1400            Blue             First
# 26  Automatic       Mumbai  38173           White            Second
# 27  Automatic       Mumbai  13000          Yellow             First
# 28  Automatic       Mumbai  14000           White  UnRegistered Car
# 29  Automatic       Mumbai   4000           Black            Second
# 30  Automatic       Mumbai   2800             Red             First
# 31  Automatic       Mumbai  14125             Red             First
# 32  Automatic       Mumbai   6000          Maroon             First
# 33  Automatic         Pune  10000            Blue             First
# 34  Automatic       Mumbai  40000             Red             First
# 35  Automatic       Mumbai  11000            Blue             First
# 36  Automatic       Mumbai  22000           Black             First
# 37  Automatic         Pune  10000            Grey            Second
# 38  Automatic       Mumbai  30000           White            Second
# 39  Automatic       Mumbai  24500            Blue            Second
# 40  Automatic       Mumbai  19710           White            Second
# 41  Automatic       Mumbai  34000      Ibis White             Third
# 42  Automatic       Mumbai  86000           White            Second
# 43     Manual       Mumbai  89000    Sandrif Grey             First
# 44     Manual       Kalyan  56000      Misty Lake            Second
# 45  Automatic       Mumbai  30000          Yellow             First
# 46  Automatic       Mumbai   1000   Grigio Titans             First
# 47  Automatic       Mumbai  50000          Silver            Second
#
#                                                engine    seating  \
# 0   3498 cc, 6 Cylinders In V Shape, 4 Valves/Cyli...         4
# 1      2993 cc, 6 Cylinders Inline, 4 Valves/Cylinder         5
# 2                                            250 Kmph         4
# 3                                                   -          -
# 4   1984 cc, 4 Cylinders Inline, 4 Valves/Cylinder...         2
# 5   1998 cc, 4 Cylinders Inline, 4 Valves/Cylinder...         4
# 6      1796 cc, 4 Cylinders Inline, 4 Valves/Cylinder         2
# 7      1796 cc, 4 Cylinders Inline, 4 Valves/Cylinder         2
# 8                                                   -          -
# 9   1984 cc, 4 Cylinders Inline, 4 Valves/Cylinder...         2
# 10  1984 cc, 4 Cylinders Inline, 4 Valves/Cylinder...         2
# 11  4951 cc, 8 Cylinders In V Shape, 4 Valves/Cyli...         4
# 12  1798 cc, 4 Cylinders Inline, 4 Valves/Cylinder...         4
# 13  5998 cc, 6 Cylinders In W Shape, 4 Valves/Cyli...         4
# 14                                                  -          -
# 15  4735 cc, 8 Cylinders In V Shape, 4 Valves/Cyli...         2
# 16  4691 cc, 8 Cylinders In V Shape, 4 Valves/Cyli...         4
# 17  1988 cc, 4 Cylinders Flat, 4 Valves/Cylinder, ...         2
# 18     2993 cc, 6 Cylinders Inline, 4 Valves/Cylinder         5
# 19  4163 cc, 8 Cylinders In V Shape, 4 Valves/Cyli...         5
# 20     2993 cc, 6 Cylinders Inline, 4 Valves/Cylinder         5
# 21  2996 cc, 6 Cylinders In V Shape, 4 Valves/Cyli...         2
# 22  2995 cc, 6 Cylinders In V Shape, 4 Valves/Cyli...         2
# 23  1798 cc, 4 Cylinders Inline, 4 Valves/Cylinder...         4
# 24                                                  -          -
# 25  1968 cc, 4 Cylinders Inline, 4 Valves/Cylinder...         4
# 26                                                  -          -
# 27  3800 cc, 6 Cylinders Flat, 4 Valves/Cylinder, ...         4
# 28  2993 cc, 6 Cylinders In V Shape, 4 Valves/Cyli...         4
# 29  1991 cc, 4 Cylinders Inline, 4 Valves/Cylinder...         4
# 30  1998 cc, 4 Cylinders Inline, 4 Valves/Cylinder...         4
# 31  1798 cc, 4 Cylinders Inline, 4 Valves/Cylinder...         4
# 32  5998 cc, 12 Cylinders In W Shape, 4 Valves/Cyl...         4
# 33  1998 cc, 4 Cylinders Inline, 4 Valves/Cylinder...         4
# 34  2996 cc, 6 Cylinders In V Shape, 4 Valves/Cyli...         4
# 35  1499 cc, 3 Cylinders Inline, 4 Valves/Cylinder...         4
# 36  2996 cc, 6 Cylinders In V Shape, 4 Valves/Cyli...         2
# 37  5998 cc, 12 Cylinders In W Shape, 4 Valves/Cyl...         4
# 38                                                  -          -
# 39  4163 cc, 8 Cylinders In V Shape, 4 Valves/Cyli...         5
# 40                                3498 cc, In V Shape  80 litres
# 41  3189 cc, 6 Cylinders In V Shape, 4 Valves/Cyli...         4
# 42                                                  -          -
# 43  1199 cc, 4 Cylinders Inline, 4 Valves/Cylinder...         5
# 44  1199 cc, 4 Cylinders Inline, 4 Valves/Cylinder...         5
# 45                                             Petrol          -
# 46  5204 cc, 10 Cylinders In V Shape, 4 Valves/Cyl...         2
# 47                                                  -          -
#
#                  Body
# 0   coupe/convertible
# 1   coupe/convertible
# 2   coupe/convertible
# 3   coupe/convertible
# 4   coupe/convertible
# 5   coupe/convertible
# 6   coupe/convertible
# 7   coupe/convertible
# 8   coupe/convertible
# 9   coupe/convertible
# 10  coupe/convertible
# 11  coupe/convertible
# 12  coupe/convertible
# 13  coupe/convertible
# 14  coupe/convertible
# 15  coupe/convertible
# 16  coupe/convertible
# 17  coupe/convertible
# 18  coupe/convertible
# 19  coupe/convertible
# 20  coupe/convertible
# 21  coupe/convertible
# 22  coupe/convertible
# 23  coupe/convertible
# 24  coupe/convertible
# 25  coupe/convertible
# 26  coupe/convertible
# 27  coupe/convertible
# 28  coupe/convertible
# 29  coupe/convertible
# 30  coupe/convertible
# 31  coupe/convertible
# 32  coupe/convertible
# 33  coupe/convertible
# 34  coupe/convertible
# 35  coupe/convertible
# 36  coupe/convertible
# 37  coupe/convertible
# 38  coupe/convertible
# 39  coupe/convertible
# 40  coupe/convertible
# 41  coupe/convertible
# 42  coupe/convertible
# 43  coupe/convertible
# 44  coupe/convertible
# 45  coupe/convertible
# 46  coupe/convertible
# 47  coupe/convertible

# %%
cars_mumbai = pd.concat([hatch_mum, suv_mum, sdn_mum,cpe_mum], axis = 0, ignore_index = True)

# %%
cars_mumbai
# Out:
#         price      year           make      model             fuel      trans  \
# 0       3.35     2011.0        Hyundai        i20           Petrol     Manual
# 1        4.2     2014.0  Maruti Suzuki      Swift           Petrol     Manual
# 2       5.65     2017.0        Hyundai  Grand i10           Petrol  Automatic
# 3      10.74     2020.0     Volkswagen       Polo           Petrol  Automatic
# 4        3.2     2013.0  Maruti Suzuki    Wagon R           Petrol     Manual
# ..        ...       ...            ...        ...              ...        ...
# 782      1.5   Apr 2011      Chevrolet       Beat  Petrol + Petrol     Manual
# 783      1.3   Nov 2011      Chevrolet       Beat           Petrol     Manual
# 784       48   Jun 2013            BMW   6-Series           Petrol  Automatic
# 785   3 Crore  Apr 2020    Lamborghini    Huracan           Petrol  Automatic
# 786      8.5   Mar 2011            BMW   3-Series           Diesel  Automatic
#
#     location    mile          color             owner  \
# 0      Thane  19130           White             First
# 1      Thane  56123             Red             First
# 2     Mumbai  44284           White             First
# 3     Mumbai   9100             Red  UnRegistered Car
# 4     Mumbai  41846           Brown             First
# ..       ...     ...            ...               ...
# 782   Mumbai  89000    Sandrif Grey             First
# 783   Kalyan  56000      Misty Lake            Second
# 784   Mumbai  30000          Yellow             First
# 785   Mumbai   1000   Grigio Titans             First
# 786   Mumbai  50000          Silver            Second
#
#                                                 engine seating  \
# 0                                                    -       -
# 1    1197 cc, 4 Cylinders Inline, 4 Valves/Cylinder...      5
# 2    1197 cc, 4 Cylinders Inline, 4 Valves/Cylinder...      5
# 3    1197 cc, 4 Cylinders Inline, 4 Valves/Cylinder...      5
# 4                998 cc, 3 Cylinders 4 Valves/Cylinder      5
# ..                                                 ...     ...
# 782  1199 cc, 4 Cylinders Inline, 4 Valves/Cylinder...      5
# 783  1199 cc, 4 Cylinders Inline, 4 Valves/Cylinder...      5
# 784                                             Petrol       -
# 785  5204 cc, 10 Cylinders In V Shape, 4 Valves/Cyl...      2
# 786                                                  -       -
#
#                   Body
# 0            hatchback
# 1            hatchback
# 2            hatchback
# 3            hatchback
# 4            hatchback
# ..                 ...
# 782  coupe/convertible
# 783  coupe/convertible
# 784  coupe/convertible
# 785  coupe/convertible
# 786  coupe/convertible
#
# [787 rows x 13 columns]

# %%
cars_mumbai.to_csv('cars_mumbai',index = False)
