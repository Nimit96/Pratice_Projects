# %%
from selenium import webdriver
import pandas as pd
import numpy as np
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
import time

# %%
driver = webdriver.Chrome("chromedriver.exe")
time.sleep(10)
url = 'https://www.cardekho.com/'
driver.get(url)

# %%
action = ActionChains(driver)
hvr = driver.find_element_by_xpath('/html/body/div[2]/div/header/div[2]/div/div/nav/ul/li[2]/span/span')
action.move_to_element(hvr).perform()
time.sleep(2)
hvr2 = driver.find_element_by_xpath('/html/body/div[2]/div/header/div[2]/div/div/nav/ul/li[2]/ul/li[1]/a/span')
action.move_to_element(hvr2).perform()
time.sleep(2)
clk = driver.find_element_by_xpath('/html/body/div[2]/div/header/div[2]/div/div/nav/ul/li[2]/ul/li[1]/ul/li[2]/a/span')
clk.click()

# %%
html = driver.find_element_by_tag_name('html')
html.send_keys(Keys.END)
time.sleep(1)
hatch = driver.find_element_by_xpath('//ul[@class="checkBoxWrap bodyTypes cd-bodyTicon"]//li[1]')
hatch.click()
time.sleep(3)
ass = driver.find_element_by_xpath('//label[@class="onoffswitch-label"]')
ass.click()

# %%
for i in range(0,100):
    driver.execute_script("window.scrollBy(0,1000)")
    time.sleep(1)
    driver.execute_script("window.scrollBy(0,-500)")

# %%
links = []

ur = driver.find_elements_by_xpath('//div[@class="gsc_col-xs-7 carsName"]//a')
for i in ur:
    links.append(i.get_attribute('href'))
len(links)
# Out:
# 216

# %%
price = []
year = []
title = []
fuel = []
trans = []
mile = []
color = []
owner =[]
engine = []
seats = []

for link in links:
    driver.get(link)
    time.sleep(3)

    try:
        pri = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div/div/div[2]/div[1]/div/div/div/div[1]/div[2]/div[1]/div[1]')
        price.append(pri.text.replace(',','').replace('₹',''))
    except NoSuchElementException:
        price.append('-')

    try:
        tit = driver.find_element_by_xpath('//div[@class="gsc_col-xs-12"]//h1')
        title.append(tit.text)
    except NoSuchElementException:
        title.append('-')

    try:
        ye = driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]//li[1]//div//div[2]')
        year.append(ye.text)
    except NoSuchElementException:
        year.append('-')

    try:
        fu = driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]//li[3]//div//div[2]')
        fuel.append(fu.text)
    except NoSuchElementException:
        fuel.append('-')

    try:
        mi = driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]//li[4]//div//div[2]')
        mile.append(mi.text.replace(',','').replace('kms',''))
    except NoSuchElementException:
        mile.append('-')

    try:
        no = driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]//li[6]//div//div[2]')
        owner.append(no.text)
    except NoSuchElementException:
        owner.append('-')

    try:
        tr = driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]//li[8]//div//div[2]')
        trans.append(tr.text)
    except NoSuchElementException:
        trans.append('-')

    time.sleep(3)
    act = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div/div/div[1]/div[7]/div/div/div/div')
    driver.execute_script("arguments[0].click();", act)

    det = driver.find_elements_by_xpath('//*[@id="specification-wdght"]/div/div/div/ul/li/div')

    for i in det:
        text = i.find_element_by_xpath('div[1]').text

        try:
            if text == 'Color':
                color.append(i.find_element_by_xpath('div[2]').text)
        except NoSuchElementException:
            color.append('-')

        try:
            if text == 'Engine':
                engine.append(i.find_element_by_xpath('div[2]').text.replace('CC',''))
        except NoSuchElementException:
            engine.append('-')

        try:
            if text == 'Seats':
                seats.append(i.find_element_by_xpath('div[2]').text)
        except NoSuchElementException:
            seats.append('-')

# %%
color = color.extend(['White'*19])

# %%
ahm_hatch = pd.DataFrame({})
ahm_hatch['price'] = price
ahm_hatch['year'] = year
ahm_hatch['title'] = title
ahm_hatch['fuel'] = fuel
ahm_hatch['trans'] = trans
ahm_hatch['mile'] = mile
ahm_hatch['color'] = color
ahm_hatch['owner'] =  owner
ahm_hatch['engine'] = engine
ahm_hatch['seating'] = seats
ahm_hatch['location'] = 'Bangalore'
ahm_hatch['Body'] = 'hatchback'

# %%
action = ActionChains(driver)
hvr = driver.find_element_by_xpath('/html/body/div[2]/div/header/div[2]/div/div/nav/ul/li[2]/span/span')
action.move_to_element(hvr).perform()
time.sleep(2)
hvr2 = driver.find_element_by_xpath('/html/body/div[2]/div/header/div[2]/div/div/nav/ul/li[2]/ul/li[1]/a/span')
action.move_to_element(hvr2).perform()
time.sleep(2)
clk = driver.find_element_by_xpath('/html/body/div[2]/div/header/div[2]/div/div/nav/ul/li[2]/ul/li[1]/ul/li[2]/a')
clk.click()

# %%
html = driver.find_element_by_tag_name('html')
html.send_keys(Keys.END)
time.sleep(1)
suv = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div[1]/div[2]/div/div[10]/div[2]/ul/li[3]')
suv.click()
time.sleep(3)
muv = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div[1]/div[2]/div/div[10]/div[2]/ul/li[5]')
muv.click()
time.sleep(2)
ass = driver.find_element_by_xpath('//label[@class="onoffswitch-label"]')
ass.click()

# %%
for i in range(0,3):
    driver.execute_script("window.scrollBy(0,1000)")
    time.sleep(1)
    driver.execute_script("window.scrollBy(0,-500)")

# %%
links = []

ur = driver.find_elements_by_xpath('//div[@class="gsc_col-xs-7 carsName"]//a')
for i in ur:
    links.append(i.get_attribute('href'))
len(links)
# Out:
# 25

# %%
sprice = []
syear = []
stitle = []
sfuel = []
strans = []
smile = []
scolor = []
sowner =[]
sengine = []
sseats = []

for link in links:
    driver.get(link)
    time.sleep(3)

    try:
        pri = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div/div/div[2]/div[1]/div/div/div/div[1]/div[2]/div[1]/div[1]')
        sprice.append(pri.text.replace(',','').replace('₹',''))
    except NoSuchElementException:
        sprice.append('-')

    try:
        tit = driver.find_element_by_xpath('//div[@class="gsc_col-xs-12"]//h1')
        stitle.append(tit.text)
    except NoSuchElementException:
        stitle.append('-')

    try:
        ye = driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]//li[1]//div//div[2]')
        syear.append(ye.text)
    except NoSuchElementException:
        syear.append('-')

    try:
        fu = driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]//li[3]//div//div[2]')
        sfuel.append(fu.text)
    except NoSuchElementException:
        sfuel.append('-')

    try:
        mi = driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]//li[4]//div//div[2]')
        smile.append(mi.text.replace(',','').replace('kms',''))
    except NoSuchElementException:
        smile.append('-')

    try:
        no = driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]//li[6]//div//div[2]')
        sowner.append(no.text)
    except NoSuchElementException:
        sowner.append('-')

    try:
        tr = driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]//li[8]//div//div[2]')
        strans.append(tr.text)
    except NoSuchElementException:
        strans.append('-')

    time.sleep(3)
    act = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div/div/div[1]/div[7]/div/div/div/div')
    driver.execute_script("arguments[0].click();", act)

    det = driver.find_elements_by_xpath('//*[@id="specification-wdght"]/div/div/div/ul/li/div')

    for i in det:
        text = i.find_element_by_xpath('div[1]').text

        try:
            if text == 'Color':
                scolor.append(i.find_element_by_xpath('div[2]').text)
        except NoSuchElementException:
            scolor.append('-')

        try:
            if text == 'Engine':
                sengine.append(i.find_element_by_xpath('div[2]').text.replace('CC',''))
        except NoSuchElementException:
            sengine.append('-')

        try:
            if text == 'Seats':
                sseats.append(i.find_element_by_xpath('div[2]').text)
        except NoSuchElementException:
            sseats.append('-')

# %%
scolor = scolor.extend(['Others'*5])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-d81b6013b271> in <module>
# ----> 1 scolor = scolor.extend(['Others'*5])
#       2 sseats = sseats.extend(['5'*5])
#
# AttributeError: 'NoneType' object has no attribute 'extend'

# %%
sseats = sseats.extend(['5'*5])

# %%
ahm_suv = pd.DataFrame({})
ahm_suv['price'] = sprice
ahm_suv['year'] = syear
ahm_suv['title'] = stitle
ahm_suv['fuel'] = sfuel
ahm_suv['trans'] = strans
ahm_suv['mile'] = smile
ahm_suv['color'] = scolor
ahm_suv['owner'] =  sowner
ahm_suv['engine'] = sengine
ahm_suv['seating'] = sseats
ahm_suv['location'] = 'Bangalore'
ahm_suv['Body'] = 'SUV'

# %%
action = ActionChains(driver)
hvr = driver.find_element_by_xpath('/html/body/div[2]/div/header/div[2]/div/div/nav/ul/li[2]/span/span')
action.move_to_element(hvr).perform()
time.sleep(2)
hvr2 = driver.find_element_by_xpath('/html/body/div[2]/div/header/div[2]/div/div/nav/ul/li[2]/ul/li[1]/a/span')
action.move_to_element(hvr2).perform()
time.sleep(2)
clk = driver.find_element_by_xpath('/html/body/div[2]/div/header/div[2]/div/div/nav/ul/li[2]/ul/li[1]/ul/li[2]/a')
clk.click()

# %%
html = driver.find_element_by_tag_name('html')
html.send_keys(Keys.END)
time.sleep(1)
suv = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div[1]/div[2]/div/div[10]/div[2]/ul/li[2]')
suv.click()
time.sleep(2)
ass = driver.find_element_by_xpath('//label[@class="onoffswitch-label"]')
ass.click()

# %%
for i in range(0,15):
    driver.execute_script("window.scrollBy(0,1000)")
    time.sleep(1)
    driver.execute_script("window.scrollBy(0,-500)")

# %%
links = []

ur = driver.find_elements_by_xpath('//div[@class="gsc_col-xs-7 carsName"]//a')
for i in ur:
    links.append(i.get_attribute('href'))
len(links)
# Out:
# 33

# %%
sprice = []
syear = []
stitle = []
sfuel = []
strans = []
smile = []
scolor = []
sowner =[]
sengine = []
sseats = []

for link in links:
    driver.get(link)
    time.sleep(3)

    try:
        pri = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div/div/div[2]/div[1]/div/div/div/div[1]/div[2]/div[1]/div[1]')
        sprice.append(pri.text.replace(',','').replace('₹',''))
    except NoSuchElementException:
        sprice.append('-')

    try:
        tit = driver.find_element_by_xpath('//div[@class="gsc_col-xs-12"]//h1')
        stitle.append(tit.text)
    except NoSuchElementException:
        stitle.append('-')

    try:
        ye = driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]//li[1]//div//div[2]')
        syear.append(ye.text)
    except NoSuchElementException:
        syear.append('-')

    try:
        fu = driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]//li[3]//div//div[2]')
        sfuel.append(fu.text)
    except NoSuchElementException:
        sfuel.append('-')

    try:
        mi = driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]//li[4]//div//div[2]')
        smile.append(mi.text.replace(',','').replace('kms',''))
    except NoSuchElementException:
        smile.append('-')

    try:
        no = driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]//li[6]//div//div[2]')
        sowner.append(no.text)
    except NoSuchElementException:
        sowner.append('-')

    try:
        tr = driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]//li[8]//div//div[2]')
        strans.append(tr.text)
    except NoSuchElementException:
        strans.append('-')

    time.sleep(3)
    act = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div/div/div[1]/div[7]/div/div/div/div')
    driver.execute_script("arguments[0].click();", act)

    det = driver.find_elements_by_xpath('//*[@id="specification-wdght"]/div/div/div/ul/li/div')

    for i in det:
        text = i.find_element_by_xpath('div[1]').text

        try:
            if text == 'Color':
                scolor.append(i.find_element_by_xpath('div[2]').text)
        except NoSuchElementException:
            scolor.append('-')

        try:
            if text == 'Engine':
                sengine.append(i.find_element_by_xpath('div[2]').text.replace('CC',''))
        except NoSuchElementException:
            sengine.append('-')

        try:
            if text == 'Seats':
                sseats.append(i.find_element_by_xpath('div[2]').text)
        except NoSuchElementException:
            sseats.append('-')

# %%
scolor = scolor.extend(['Others'*5])

# %%
ahm_sdn = pd.DataFrame({})
ahm_sdn['price'] = sprice
ahm_sdn['year'] = syear
ahm_sdn['title'] = stitle
ahm_sdn['fuel'] = sfuel
ahm_sdn['trans'] = strans
ahm_sdn['mile'] = smile
ahm_sdn['color'] = scolor
ahm_sdn['owner'] =  sowner
ahm_sdn['engine'] = sengine
ahm_sdn['seating'] = sseats
ahm_sdn['location'] = 'Bangalore'
ahm_sdn['Body'] = 'sedan'

# %%
bangalore = pd.concat([ahm_hatch, ahm_suv,ahm_sdn], axis = 0, ignore_index = True)
bangalore
# Out:
#        price  year                    title    fuel      trans       mile  \
# 0     463500  2015      2015 Maruti Celerio  Petrol  Automatic  29406 Kms
# 1     296000  2009         2009 Hyundai i10  Petrol     Manual  26213 Kms
# 2     410000  2015      2015 Maruti Celerio  Petrol  Automatic  50200 Kms
# 3     581000  2017           2017 Ford Figo  Diesel     Manual   5545 Kms
# 4     444500  2018        2018 Renault KWID  Petrol     Manual  22912 Kms
# ..       ...   ...                      ...     ...        ...        ...
# 269   483000  2013       2013 Hyundai Verna  Petrol     Manual  71893 Kms
# 270   501000  2012       2012 Hyundai Verna  Diesel     Manual  99274 Kms
# 271   433000  2011          2011 Honda City  Petrol     Manual  79577 Kms
# 272   673500  2016       2016 Hyundai Verna  Petrol     Manual  73275 Kms
# 273   706000  2018  2018 Maruti Swift Dzire  Petrol     Manual  26453 Kms
#
#     color      owner engine seating   location       Body
# 0    None  1st Owner   998        5  Bangalore  hatchback
# 1    None  1st Owner  1197        5  Bangalore  hatchback
# 2    None  2nd Owner   998        5  Bangalore  hatchback
# 3    None  1st Owner  1499        5  Bangalore  hatchback
# 4    None  1st Owner   999        5  Bangalore  hatchback
# ..    ...        ...    ...     ...        ...        ...
# 269  None  2nd Owner  1591        5  Bangalore      sedan
# 270  None  1st Owner  1582        5  Bangalore      sedan
# 271  None  1st Owner  1497        5  Bangalore      sedan
# 272  None  1st Owner  1591        5  Bangalore      sedan
# 273  None  1st Owner  1197        5  Bangalore      sedan
#
# [274 rows x 12 columns]

# %%
bangalore.to_excel('bangalore.xlsx', index = False)
