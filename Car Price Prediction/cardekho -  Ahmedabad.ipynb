# %%
from selenium import webdriver
import pandas as pd
import numpy as np
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
import time

# %%
driver = webdriver.Chrome("chromedriver.exe")
time.sleep(10)
url = 'https://www.cardekho.com/'
driver.get(url)

# %%
action = ActionChains(driver)
hvr = driver.find_element_by_xpath('/html/body/div[2]/div/header/div[2]/div/div/nav/ul/li[2]/span/span')
action.move_to_element(hvr).perform()
time.sleep(2)
hvr2 = driver.find_element_by_xpath('/html/body/div[2]/div/header/div[2]/div/div/nav/ul/li[2]/ul/li[1]/a/span')
action.move_to_element(hvr2).perform()
time.sleep(2)
clk = driver.find_element_by_xpath('/html/body/div[2]/div/header/div[2]/div/div/nav/ul/li[2]/ul/li[1]/ul/li[1]/a')
clk.click()

# %%
html = driver.find_element_by_tag_name('html')
html.send_keys(Keys.END)
time.sleep(1)
hatch = driver.find_element_by_xpath('//ul[@class="checkBoxWrap bodyTypes cd-bodyTicon"]//li[1]')
hatch.click()
time.sleep(3)
ass = driver.find_element_by_xpath('//label[@class="onoffswitch-label"]')
ass.click()

# %%
for i in range(0,100):
    driver.execute_script("window.scrollBy(0,1000)")
    time.sleep(1)
    driver.execute_script("window.scrollBy(0,-500)")

# %%
links = []

ur = driver.find_elements_by_xpath('//div[@class="gsc_col-xs-7 carsName"]//a')
for i in ur:
    links.append(i.get_attribute('href'))
len(links)
# Out:
# 20

# %%
price = []
year = []
title = []
fuel = []
trans = []
mile = []
color = []
owner =[]
engine = []
seats = []

for link in links:
    driver.get(link)
    time.sleep(3)

    try:
        pri = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div/div/div[2]/div[1]/div/div/div/div[1]/div[2]/div[1]/div[1]')
        price.append(pri.text.replace(',','').replace('₹',''))
    except NoSuchElementException:
        price.append('-')

    try:
        tit = driver.find_element_by_xpath('//div[@class="gsc_col-xs-12"]//h1')
        title.append(tit.text)
    except NoSuchElementException:
        title.append('-')

    try:
        ye = driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]//li[1]//div//div[2]')
        year.append(ye.text)
    except NoSuchElementException:
        year.append('-')

    try:
        fu = driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]//li[3]//div//div[2]')
        fuel.append(fu.text)
    except NoSuchElementException:
        fuel.append('-')

    try:
        mi = driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]//li[4]//div//div[2]')
        mile.append(mi.text.replace(',','').replace('kms',''))
    except NoSuchElementException:
        mile.append('-')

    try:
        no = driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]//li[6]//div//div[2]')
        owner.append(no.text)
    except NoSuchElementException:
        owner.append('-')

    try:
        tr = driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]//li[8]//div//div[2]')
        trans.append(tr.text)
    except NoSuchElementException:
        trans.append('-')

    time.sleep(3)
    act = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div/div/div[1]/div[7]/div/div/div/div')
    driver.execute_script("arguments[0].click();", act)

    det = driver.find_elements_by_xpath('//*[@id="specification-wdght"]/div/div/div/ul/li/div')

    for i in det:
        text = i.find_element_by_xpath('div[1]').text

        try:
            if text == 'Color':
                color.append(i.find_element_by_xpath('div[2]').text)
        except NoSuchElementException:
            color.append('-')

        try:
            if text == 'Engine':
                engine.append(i.find_element_by_xpath('div[2]').text.replace('CC',''))
        except NoSuchElementException:
            engine.append('-')

        try:
            if text == 'Seats':
                seats.append(i.find_element_by_xpath('div[2]').text)
        except NoSuchElementException:
            seats.append('-')

# %%
color = color.append('White')

# %%
ahm_hatch = pd.DataFrame({})
ahm_hatch['price'] = price
ahm_hatch['year'] = year
ahm_hatch['title'] = title
ahm_hatch['fuel'] = fuel
ahm_hatch['trans'] = trans
ahm_hatch['mile'] = mile
ahm_hatch['color'] = color
ahm_hatch['owner'] =  owner
ahm_hatch['engine'] = engine
ahm_hatch['seating'] = seats
ahm_hatch['location'] = 'Ahmedabad'
ahm_hatch['Body'] = 'hatchback'

# %%
action = ActionChains(driver)
hvr = driver.find_element_by_xpath('/html/body/div[2]/div/header/div[2]/div/div/nav/ul/li[2]/span/span')
action.move_to_element(hvr).perform()
time.sleep(2)
hvr2 = driver.find_element_by_xpath('/html/body/div[2]/div/header/div[2]/div/div/nav/ul/li[2]/ul/li[1]/a/span')
action.move_to_element(hvr2).perform()
time.sleep(2)
clk = driver.find_element_by_xpath('/html/body/div[2]/div/header/div[2]/div/div/nav/ul/li[2]/ul/li[1]/ul/li[1]/a')
clk.click()

# %%
html = driver.find_element_by_tag_name('html')
html.send_keys(Keys.END)
time.sleep(1)
suv = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div[1]/div[2]/div/div[10]/div[2]/ul/li[3]')
suv.click()
time.sleep(3)
muv = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div[1]/div[2]/div/div[10]/div[2]/ul/li[5]')
muv.click()
time.sleep(2)
ass = driver.find_element_by_xpath('//label[@class="onoffswitch-label"]')
ass.click()

# %%
for i in range(0,3):
    driver.execute_script("window.scrollBy(0,1000)")
    time.sleep(1)
    driver.execute_script("window.scrollBy(0,-500)")

# %%
links = []

ur = driver.find_elements_by_xpath('//div[@class="gsc_col-xs-7 carsName"]//a')
for i in ur:
    links.append(i.get_attribute('href'))
len(links)
# Out:
# 7

# %%
sprice = []
syear = []
stitle = []
sfuel = []
strans = []
smile = []
scolor = []
sowner =[]
sengine = []
sseats = []

for link in links:
    driver.get(link)
    time.sleep(3)

    try:
        pri = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div/div/div[2]/div[1]/div/div/div/div[1]/div[2]/div[1]/div[1]')
        sprice.append(pri.text.replace(',','').replace('₹',''))
    except NoSuchElementException:
        sprice.append('-')

    try:
        tit = driver.find_element_by_xpath('//div[@class="gsc_col-xs-12"]//h1')
        stitle.append(tit.text)
    except NoSuchElementException:
        stitle.append('-')

    try:
        ye = driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]//li[1]//div//div[2]')
        syear.append(ye.text)
    except NoSuchElementException:
        syear.append('-')

    try:
        fu = driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]//li[3]//div//div[2]')
        sfuel.append(fu.text)
    except NoSuchElementException:
        sfuel.append('-')

    try:
        mi = driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]//li[4]//div//div[2]')
        smile.append(mi.text.replace(',','').replace('kms',''))
    except NoSuchElementException:
        smile.append('-')

    try:
        no = driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]//li[6]//div//div[2]')
        sowner.append(no.text)
    except NoSuchElementException:
        sowner.append('-')

    try:
        tr = driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]//li[8]//div//div[2]')
        strans.append(tr.text)
    except NoSuchElementException:
        strans.append('-')

    time.sleep(3)
    act = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div/div/div[1]/div[7]/div/div/div/div')
    driver.execute_script("arguments[0].click();", act)

    det = driver.find_elements_by_xpath('//*[@id="specification-wdght"]/div/div/div/ul/li/div')

    for i in det:
        text = i.find_element_by_xpath('div[1]').text

        try:
            if text == 'Color':
                scolor.append(i.find_element_by_xpath('div[2]').text)
        except NoSuchElementException:
            scolor.append('-')

        try:
            if text == 'Engine':
                sengine.append(i.find_element_by_xpath('div[2]').text.replace('CC',''))
        except NoSuchElementException:
            sengine.append('-')

        try:
            if text == 'Seats':
                sseats.append(i.find_element_by_xpath('div[2]').text)
        except NoSuchElementException:
            sseats.append('-')

# %%
ahm_suv = pd.DataFrame({})
ahm_suv['price'] = sprice
ahm_suv['year'] = syear
ahm_suv['title'] = stitle
ahm_suv['fuel'] = sfuel
ahm_suv['trans'] = strans
ahm_suv['mile'] = smile
ahm_suv['color'] = scolor
ahm_suv['owner'] =  sowner
ahm_suv['engine'] = sengine
ahm_suv['seating'] = sseats
ahm_suv['location'] = 'Ahmedabad'
ahm_suv['Body'] = 'SUV'

# %%
action = ActionChains(driver)
hvr = driver.find_element_by_xpath('/html/body/div[2]/div/header/div[2]/div/div/nav/ul/li[2]/span/span')
action.move_to_element(hvr).perform()
time.sleep(2)
hvr2 = driver.find_element_by_xpath('/html/body/div[2]/div/header/div[2]/div/div/nav/ul/li[2]/ul/li[1]/a/span')
action.move_to_element(hvr2).perform()
time.sleep(2)
clk = driver.find_element_by_xpath('/html/body/div[2]/div/header/div[2]/div/div/nav/ul/li[2]/ul/li[1]/ul/li[1]/a')
clk.click()

# %%
html = driver.find_element_by_tag_name('html')
html.send_keys(Keys.END)
time.sleep(1)
suv = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div[1]/div[2]/div/div[10]/div[2]/ul/li[2]')
suv.click()
time.sleep(2)
ass = driver.find_element_by_xpath('//label[@class="onoffswitch-label"]')
ass.click()

# %%
links = []

ur = driver.find_elements_by_xpath('//div[@class="gsc_col-xs-7 carsName"]//a')
for i in ur:
    links.append(i.get_attribute('href'))
len(links)
# Out:
# 12

# %%
sprice = []
syear = []
stitle = []
sfuel = []
strans = []
smile = []
scolor = []
sowner =[]
sengine = []
sseats = []

for link in links:
    driver.get(link)
    time.sleep(3)

    try:
        pri = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div/div/div[2]/div[1]/div/div/div/div[1]/div[2]/div[1]/div[1]')
        sprice.append(pri.text.replace(',','').replace('₹',''))
    except NoSuchElementException:
        sprice.append('-')

    try:
        tit = driver.find_element_by_xpath('//div[@class="gsc_col-xs-12"]//h1')
        stitle.append(tit.text)
    except NoSuchElementException:
        stitle.append('-')

    try:
        ye = driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]//li[1]//div//div[2]')
        syear.append(ye.text)
    except NoSuchElementException:
        syear.append('-')

    try:
        fu = driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]//li[3]//div//div[2]')
        sfuel.append(fu.text)
    except NoSuchElementException:
        sfuel.append('-')

    try:
        mi = driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]//li[4]//div//div[2]')
        smile.append(mi.text.replace(',','').replace('kms',''))
    except NoSuchElementException:
        smile.append('-')

    try:
        no = driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]//li[6]//div//div[2]')
        sowner.append(no.text)
    except NoSuchElementException:
        sowner.append('-')

    try:
        tr = driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]//li[8]//div//div[2]')
        strans.append(tr.text)
    except NoSuchElementException:
        strans.append('-')

    time.sleep(3)
    act = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div/div/div[1]/div[7]/div/div/div/div')
    driver.execute_script("arguments[0].click();", act)

    det = driver.find_elements_by_xpath('//*[@id="specification-wdght"]/div/div/div/ul/li/div')

    for i in det:
        text = i.find_element_by_xpath('div[1]').text

        try:
            if text == 'Color':
                scolor.append(i.find_element_by_xpath('div[2]').text)
        except NoSuchElementException:
            scolor.append('-')

        try:
            if text == 'Engine':
                sengine.append(i.find_element_by_xpath('div[2]').text.replace('CC',''))
        except NoSuchElementException:
            sengine.append('-')

        try:
            if text == 'Seats':
                sseats.append(i.find_element_by_xpath('div[2]').text)
        except NoSuchElementException:
            sseats.append('-')

# %%
ahm_sdn = pd.DataFrame({})
ahm_sdn['price'] = sprice
ahm_sdn['year'] = syear
ahm_sdn['title'] = stitle
ahm_sdn['fuel'] = sfuel
ahm_sdn['trans'] = strans
ahm_sdn['mile'] = smile
ahm_sdn['color'] = scolor
ahm_sdn['owner'] =  sowner
ahm_sdn['engine'] = sengine
ahm_sdn['seating'] = sseats
ahm_sdn['location'] = 'Ahmedabad'
ahm_sdn['Body'] = 'sedan'

# %%
ahmedabad = pd.concat([ahm_hatch, ahm_suv,ahm_sdn], axis = 0, ignore_index = True)
ahmedabad
# Out:
#       price  year                    title    fuel      trans        mile  \
# 0    422000  2019     2019 Maruti S-Presso  Petrol     Manual   24230 Kms
# 1    585000  2018        2018 Maruti Swift  Diesel     Manual   31694 Kms
# 2    610000  2017       2017 Maruti Baleno  Petrol     Manual   49072 Kms
# 3    399000  2013        2013 Maruti Swift  Diesel     Manual   72301 Kms
# 4    600000  2019        2019 Maruti Swift  Petrol     Manual   21060 Kms
# 5    482500  2016       2016 Maruti Baleno  Petrol     Manual   51069 Kms
# 6    328500  2014      2014 Maruti Wagon R  Petrol     Manual   42381 Kms
# 7    279500  2013      2014 Maruti Wagon R  Petrol     Manual   85416 Kms
# 8    506500  2020      2020 Maruti Wagon R  Petrol     Manual   10371 Kms
# 9    387000  2017      2017 Maruti Wagon R  Petrol     Manual   43031 Kms
# 10   535500  2017       2017 Maruti Baleno  Petrol     Manual   34669 Kms
# 11   294500  2014      2014 Maruti Wagon R  Petrol     Manual  131125 Kms
# 12   267500  2011      2011 Maruti Wagon R  Petrol     Manual   60689 Kms
# 13   430000  2017      2017 Maruti Wagon R  Petrol  Automatic   41174 Kms
# 14   464000  2016        2016 Maruti Swift  Petrol     Manual   45090 Kms
# 15   480500  2015   2015 Hyundai Grand i10  Petrol     Manual   73875 Kms
# 16   665000  2019  2019 Maruti Swift Dzire  Petrol     Manual    9718 Kms
# 17   399500  2011          2011 Honda City  Petrol     Manual   38647 Kms
# 18   177500  2012     2012 Maruti Alto K10  Petrol     Manual   89579 Kms
